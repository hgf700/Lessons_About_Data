# %% [markdown]
# Import wymaganych bibliotek

# %% [markdown]
# # **Laboratorium 2** - Podstawowe operacje arytmetyczne w analizie danych

# %%
import pandas as pd
import numpy as np
import matplotlib as mat
import plotly as pl
from kagglehub import KaggleDatasetAdapter
import json
import os

# %%
data_set_path = "XAU_15m_data.csv"
df = kagglehub.dataset_load(
    KaggleDatasetAdapter.PANDAS,
    "novandraanugrah/xauusd-gold-price-historical-data-2004-2024",
    data_set_path,
    pandas_kwargs={"delimiter" : ";"}
)
df.head()
# Out:
# Downloading to C:\Users\USER098\.cache\kagglehub\datasets\novandraanugrah\xauusd-gold-price-historical-data-2004-2024\versions\10\XAU_15m_data.csv...
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████| 24.4M/24.4M [00:02<00:00, 11.1MB/s]
#                Date   Open   High    Low  Close  Volume
# 0  2004.06.11 07:15  384.0  384.3  383.8  384.3      12
# 1  2004.06.11 07:30  383.8  384.3  383.6  383.8      12
# 2  2004.06.11 07:45  383.3  383.8  383.3  383.8      20
# 3  2004.06.11 08:00  383.8  384.1  383.6  383.6       8
# 4  2004.06.11 08:15  383.6  384.3  383.5  383.5      20

# %% [markdown]
# Poodstawowe operacje matematyczne na zbiorze danych:
#
# 2.1. Średnia arytmetyczna
#
# ![image.png](data:image/png;base64,...)

# %%
np.max(df["High"])
# Out:
# np.float64(4550.16)

# %%
np.min(df["High"])
# Out:
# np.float64(381.6)

# %%
np.mean(df["High"])
# Out:
# np.float64(1417.8529401335593)

# %% [markdown]
# 2.2. Mediana
#
# ![image.png](data:image/png;base64,...)

# %%
len(df["High"])
# Out:
# 492964

# %%
np.median(df["High"])
# Out:
# np.float64(1305.24)

# %% [markdown]
# 2.3. Odchylenie standardowe
#
# ![image.png](data:image/png;base64,...)

# %%
np.std(df["High"])
# Out:
# np.float64(650.9215886605778)

# %% [markdown]
# 2.4. Wariancja
#
# ![image.png](data:image/png;base64,...)

# %%
np.var(df["High"])
# Out:
# np.float64(423698.9145844103)

# %% [markdown]
# 2.5. Korelacja
#
# ![image.png](data:image/png;base64,...)

# %%
np.corrcoef(df["High"], df["Low"])[0,1]
# Out:
# np.float64(0.999996107746964)

# %% [markdown]
# 2.6. Kowariancja
#
# ![image.png](data:image/png;base64,...)

# %%
covariance = np.cov(df["High"], df["Low"])
covariance
# Out:
# array([[423699.77407876, 423052.65590882],
#        [423052.65590882, 422409.81433012]])

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
np.corrcoef(df["High"], df["Low"])[0,1]
# Out:
# np.float64(0.999996107746964)

# %%
corelation = covariance[0,1] / (np.sqrt(covariance[0,0]) * np.sqrt(covariance[1,1]))
corelation
# Out:
# np.float64(0.9999961077469639)
